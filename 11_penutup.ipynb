# %% [markdown]
# # Bab 11: Penutup
#
# Selamat, kamu sudah menyelesaikan fondasi Python basic dari variabel sampai struktur data utama.

# %% [markdown]
# **Navigasi:** Prev: [10_list_vs_dict_vs_set_vs_tuple.ipynb](10_list_vs_dict_vs_set_vs_tuple.ipynb) | Next: [99_kunci_jawaban.ipynb](99_kunci_jawaban.ipynb)

# %% [markdown]
# ## 11.1 Ringkasan Seluruh Materi
# - Bab 1: variabel, ekspresi, input, dan konversi tipe.
# - Bab 2: percabangan untuk pengambilan keputusan.
# - Bab 3: fungsi agar kode lebih rapi dan reusable.
# - Bab 4: perulangan untuk proses berulang.
# - Bab 5: string untuk pengolahan teks.
# - Bab 6: list untuk data berurutan yang fleksibel.
# - Bab 7: dictionary untuk data berlabel `key: value`.
# - Bab 8: set untuk data unik dan operasi himpunan.
# - Bab 9: tuple untuk data tetap.
# - Bab 10: memilih struktur data yang tepat sesuai konteks.

# %% [markdown]
# ## 11.2 Skill yang Sekarang Kamu Punya
# - Bisa membaca dan menulis kode Python dasar.
# - Bisa memecah masalah menjadi langkah kecil.
# - Bisa memilih struktur data yang sesuai kebutuhan.
# - Bisa menjalankan notebook dan melakukan eksperimen mandiri.

# %% [markdown]
# ## 11.3 Saran Lanjutan Belajar
# 1. Ulangi latihan tanpa melihat contoh.
# 2. Ubah beberapa latihan menjadi program `.py`.
# 3. Mulai topik berikutnya: file I/O, error handling, dan OOP dasar.
# 4. Bangun mini project kecil (misal: pencatat pengeluaran, to-do list, kuis sederhana).

# %%
# Aksi kecil: cetak motivasi belajar
pesan = 'Konsisten 20 menit per hari lebih kuat daripada maraton sesekali.'
print(pesan)
# Out:
# Konsisten 20 menit per hari lebih kuat daripada maraton sesekali.

# %% [markdown]
# ## 11.4 Terima Kasih
# Terima kasih sudah belajar sampai akhir. Terus praktik, karena kemampuan coding tumbuh dari jam terbang, bukan hafalan.

# %% [markdown]
# **Navigasi:** Prev: [10_list_vs_dict_vs_set_vs_tuple.ipynb](10_list_vs_dict_vs_set_vs_tuple.ipynb) | Next: [99_kunci_jawaban.ipynb](99_kunci_jawaban.ipynb)
